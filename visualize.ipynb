# %%
# %matplotlib inline
from baselines.common import plot_util as pu
import matplotlib.pyplot as plt

# %%
LOG_DIRS = 'results/logs/doublependulum/'
results = pu.load_results(LOG_DIRS)
fig = pu.plot_results(results, average_group=True, split_fn=lambda _: '', shaded_std=False, resample=32)
plt.title('InvertedDoublePendulum-v2')
plt.show()
# Out:
# /home/pietro/Desktop/baselines/baselines/bench/monitor.py:162: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.headers = headers # HACK to preserve backwards compatibility

# %%
LOG_DIRS = 'results/logs/mountaincar/'
results = pu.load_results(LOG_DIRS)
fig = pu.plot_results(results, average_group=True, split_fn=lambda _: '', shaded_std=False, resample=32)
plt.title('MountainCar-v0')
plt.show()
# Out:
# /home/pietro/Desktop/baselines/baselines/bench/monitor.py:162: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.headers = headers # HACK to preserve backwards compatibility
